# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['credit card fraud.ipynb', 'creditcard.csv']

# %%
df=pd.read_csv('creditcard.csv',encoding='latin_1')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.isnull().sum().max()
# Out:
# np.int64(0)

# %%
df['Time']=df['Time'].apply(lambda sec:(sec/3600))
df
# Out:
#              Time         V1         V2        V3        V4        V5  \
# 0        0.000000  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1        0.000000   1.191857   0.266151  0.166480  0.448154  0.060018
# 2        0.000278  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3        0.000278  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4        0.000556  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...           ...        ...        ...       ...       ...       ...
# 284802  47.996111 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  47.996389  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  47.996667   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  47.996667  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  47.997778  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
df['amount_minmax']=mm.fit_transform(df['Amount'].values.reshape(-1,1))
df
# Out:
#              Time         V1         V2        V3        V4        V5  \
# 0        0.000000  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1        0.000000   1.191857   0.266151  0.166480  0.448154  0.060018
# 2        0.000278  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3        0.000278  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4        0.000556  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...           ...        ...        ...       ...       ...       ...
# 284802  47.996111 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  47.996389  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  47.996667   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  47.996667  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  47.997778  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V22       V23  \
# 0       0.462388  0.239599  0.098698  0.363787  ...  0.277838 -0.110474
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.638672  0.101288
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.771679  0.909412
# 3       1.247203  0.237609  0.377436 -1.387024  ...  0.005274 -0.190321
# 4       0.095921  0.592941 -0.270533  0.817739  ...  0.798278 -0.137458
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.111864  1.014480
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.924384  0.012463
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.578229 -0.037501
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.800049 -0.163298
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.643078  0.376777
#
#              V24       V25       V26       V27       V28  Amount  Class  \
# 0       0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1      -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2      -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3      -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4       0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 284802 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77      0
# 284803 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79      0
# 284804  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88      0
# 284805  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00      0
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00      0
#
#         amount_minmax
# 0            0.005824
# 1            0.000105
# 2            0.014739
# 3            0.004807
# 4            0.002724
# ...               ...
# 284802       0.000030
# 284803       0.000965
# 284804       0.002642
# 284805       0.000389
# 284806       0.008446
#
# [284807 rows x 32 columns]

# %%
X=df.drop(['Time','Class','amount_minmax','Amount'],axis=1)
y=df['Class']
X
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V19       V20  \
# 0       0.239599  0.098698  0.363787  0.090794  ...  0.403993  0.251412
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.145783 -0.069083
# 2       0.791461  0.247676 -1.514654  0.207643  ... -2.261857  0.524980
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -1.232622 -0.208038
# 4       0.592941 -0.270533  0.817739  0.753074  ...  0.803487  0.408542
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ... -0.682920  1.475829
# 284803  0.024330  0.294869  0.584800 -0.975926  ... -1.545556  0.059616
# 284804 -0.296827  0.708417  0.432454 -0.484782  ... -0.577252  0.001396
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  2.897849  0.127434
# 284806  1.577006 -0.414650  0.486180 -0.915427  ... -0.256117  0.382948
#
#              V21       V22       V23       V24       V25       V26       V27  \
# 0      -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1      -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2       0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3      -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4      -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.213454  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651
# 284803  0.214205  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472
# 284804  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455
# 284805  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821
# 284806  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415
#
#              V28
# 0      -0.021053
# 1       0.014724
# 2      -0.059752
# 3       0.061458
# 4       0.215153
# ...          ...
# 284802  0.823731
# 284803 -0.053527
# 284804 -0.026561
# 284805  0.104533
# 284806  0.013649
#
# [284807 rows x 28 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,shuffle=True)
X_train.shape
# Out:
# (199364, 28)

# %%
X_test.shape
# Out:
# (85443, 28)

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(X_test)

# %%
roc_auc_score(y_test,y_pred)
# Out:
# np.float64(0.7729501061073267)

# %%
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85291
#            1       0.86      0.55      0.67       152
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.77      0.83     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[85278    13]
#  [   69    83]]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9990402958697612

# %%
from sklearn.metrics import f1_score
f1_score(y_test,y_pred)
# Out:
# np.float64(0.6693548387096774)

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imblearn) (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (1.14.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
s=SMOTE()

# %%
from collections import Counter
Counter(y_train)
# Out:
# Counter({0: 199024, 1: 340})

# %%
X_train_smote,y_train_smote=s.fit_resample(X_train,y_train)

# %%
Counter(y_train_smote)
# Out:
# Counter({0: 199024, 1: 199024})

# %%
lg=LogisticRegression()
lg.fit(X_train_smote,y_train_smote)
y_pred=lg.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85291
#            1       0.06      0.89      0.12       152
#
#     accuracy                           0.98     85443
#    macro avg       0.53      0.94      0.55     85443
# weighted avg       1.00      0.98      0.99     85443

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[83332  1959]
#  [   16   136]]

# %%
f1_score(y_pred,y_test)
# Out:
# np.float64(0.12105028927458834)

# %%
print(roc_auc_score(y_test,y_pred))
# Out:
# 0.9358842081814025
